# %%
import pandas as pd
pd.set_option("display.max_columns",50)

# %%
PATH = "/Users/ekselan/Desktop/LAMBDA/LABS/Labs26-Citrics-DS-TeamA/data/census/sub-est2019_all.csv"

df = pd.read_csv(PATH, encoding="latin_1")

df.columns = [x.lower() for x in df.columns.to_list()]
print(df.shape)
df.head()
# Out:
# (81434, 22)
#    sumlev  state  county  place  cousub  concit  primgeo_flag funcstat  \
# 0      40      1       0      0       0       0             0        A
# 1     162      1       0    124       0       0             0        A
# 2     162      1       0    460       0       0             0        A
# 3     162      1       0    484       0       0             0        A
# 4     162      1       0    676       0       0             0        A
#
#               name   stname census2010pop  estimatesbase2010  popestimate2010  \
# 0          Alabama  Alabama       4779736            4780125          4785437
# 1   Abbeville city  Alabama          2688               2705             2699
# 2  Adamsville city  Alabama          4522               4506             4500
# 3     Addison town  Alabama           758                754              751
# 4       Akron town  Alabama           356                356              355
#
# ...

# %%
census = df.drop([
    "sumlev",
    "state",
    "county",
    "place",
    "cousub",
    "concit",
    "primgeo_flag",
    "funcstat"
], axis=1)

census = census.rename(columns={
    "name":"city",
    "stname":"state"
})

print(census.shape)
census.head()
# Out:
# (81434, 14)
#               city    state census2010pop  estimatesbase2010  popestimate2010  \
# 0          Alabama  Alabama       4779736            4780125          4785437
# 1   Abbeville city  Alabama          2688               2705             2699
# 2  Adamsville city  Alabama          4522               4506             4500
# 3     Addison town  Alabama           758                754              751
# 4       Akron town  Alabama           356                356              355
#
#    popestimate2011  popestimate2012  popestimate2013  popestimate2014  \
# 0          4799069          4815588          4830081          4841799
# 1             2694             2643             2628             2608
# 2             4493             4471             4449             4420
# 3              750              743              742              739
# 4              347              347              343              338
#
# ...

# %%
census.isnull().sum()
# Out:
# city                 0
# state                0
# census2010pop        0
# estimatesbase2010    0
# popestimate2010      0
# popestimate2011      0
# popestimate2012      0
# popestimate2013      0
# popestimate2014      0
# popestimate2015      0
# popestimate2016      0
# popestimate2017      0
# popestimate2018      0
# popestimate2019      0
# dtype: int64

# %%
census.city.nunique()
# 31,802 Unique City Names
# Out:
# 31802

# %%
census.state.nunique()
# 51 Unique State Names
# Out:
# 51

# %%
census.state.unique()
 # Problem here is state names are fully spelled out
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
census = census.replace({
    "Alabama":"AL",
    "Alaska":"AK",
    "Arizona":"AZ",
    "Arkansas":"AR",
    "California":"CA",
    "Colorado":"CO",
    "Connecticut":"CT",
    "Delaware":"DE",
    "District of Columbia":"DC",
    "Florida":"FL",
    "Georgia":"GA",
    "Hawaii":"HI",
    "Idaho":"ID",
    "Illinois":"IL",
    "Indiana":"IN",
    "Iowa":"IA",
    "Kansas":"KS",
    "Kentucky":"KY",
    "Louisiana":"LA",
    "Maine":"ME",
    "Maryland":"MD",
    "Massachusetts":"MA",
    "Michigan":"MI",
    "Minnesota":"MN",
    "Mississippi":"MS",
    "Missouri":"MO",
    "Montana":"MT",
    "Nebraska":"NE",
    "Nevada":"NV",
    "New Hampshire":"NH",
    "New Jersey":"NJ",
    "New Mexico":"NM",
    "New York":"NY",
    "North Carolina":"NC",
    "North Dakota":"ND",
    "Ohio":"OH",
    "Oklahoma":"OK",
    "Oregon":"OR",
    "Pennsylvania":"PA",
    "Rhode Island":"RI",
    "South Carolina":"SC",
    "South Dakota":"SD",
    "Tennessee":"TN",
    "Texas":"TX",
    "Utah":"UT",
    "Vermont":"VT",
    "Virginia":"VA",
    "Washington":"WA",
    "West Virginia":"WV",
    "Wisconsin":"WI",
    "Wyoming":"WY"
})

# %%
print(census.state.nunique())
census.state.unique()
# Out:
# 51
# array(['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA',
#        'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA',
#        'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY',
#        'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY'], dtype=object)

# %%
print(census.shape)
census.head()
# Out:
# (81434, 14)
#               city state census2010pop  estimatesbase2010  popestimate2010  \
# 0               AL    AL       4779736            4780125          4785437
# 1   Abbeville city    AL          2688               2705             2699
# 2  Adamsville city    AL          4522               4506             4500
# 3     Addison town    AL           758                754              751
# 4       Akron town    AL           356                356              355
#
#    popestimate2011  popestimate2012  popestimate2013  popestimate2014  \
# 0          4799069          4815588          4830081          4841799
# 1             2694             2643             2628             2608
# 2             4493             4471             4449             4420
# 3              750              743              742              739
# 4              347              347              343              338
#
#    popestimate2015  popestimate2016  popestimate2017  popestimate2018  \
# ...

# %%
census.isnull().sum()
# Out:
# city                 0
# state                0
# census2010pop        0
# estimatesbase2010    0
# popestimate2010      0
# popestimate2011      0
# popestimate2012      0
# popestimate2013      0
# popestimate2014      0
# popestimate2015      0
# popestimate2016      0
# popestimate2017      0
# popestimate2018      0
# popestimate2019      0
# dtype: int64

# %%
census.dtypes
# Out:
# city                 object
# state                object
# census2010pop        object
# estimatesbase2010     int64
# popestimate2010       int64
# popestimate2011       int64
# popestimate2012       int64
# popestimate2013       int64
# popestimate2014       int64
# popestimate2015       int64
# popestimate2016       int64
# popestimate2017       int64
# popestimate2018       int64
# popestimate2019       int64
# dtype: object

# %%
census.census2010pop = [int(x) for x in census.census2010pop.to_list()]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-618b3628ea7c> in <module>
# ----> 1 census.census2010pop = [int(x) for x in census.census2010pop.to_list()]
#
# <ipython-input-29-618b3628ea7c> in <listcomp>(.0)
# ----> 1 census.census2010pop = [int(x) for x in census.census2010pop.to_list()]
#
# ValueError: invalid literal for int() with base 10: 'A'

# %%
census.sort_values("census2010pop")
# Out:
#                                 city state census2010pop  estimatesbase2010  \
# 35044            Nashwauk city (pt.)    MN             0                  0
# 16301           Frankfort city (pt.)    IN             0                 18
# 37673            Hastings city (pt.)    MN             0                  0
# 59387  North Baltimore village (pt.)    OH             0                  0
# 43379              Minden city (pt.)    NE             0                  0
# ...                              ...   ...           ...                ...
# 77797                Windsor village    WI             A               6308
# 50685              Candor town (pt.)    NC             A                  0
# 77730                 Summit village    WI             A               4642
# 77402           Fox Crossing village    WI             A              18227
# 32270                      Caro city    MI             A               4261
#
# ...

# %%
census["census2010pop"] = census["census2010pop"].replace("A","0")

# %%
census.census2010pop = [int(x) for x in census.census2010pop.to_list()]

# %%
census.dtypes
# Out:
# city                 object
# state                object
# census2010pop         int64
# estimatesbase2010     int64
# popestimate2010       int64
# popestimate2011       int64
# popestimate2012       int64
# popestimate2013       int64
# popestimate2014       int64
# popestimate2015       int64
# popestimate2016       int64
# popestimate2017       int64
# popestimate2018       int64
# popestimate2019       int64
# dtype: object

# %%
# Dtypes appropriate, state names corrected, no null vals. Proceed to export

PATH = "/Users/ekselan/Desktop/LAMBDA/LABS/Labs26-Citrics-DS-TeamA/data/census/cleaned_census_data.csv"

census.to_csv(PATH, index=False)
